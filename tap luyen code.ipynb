# %% [markdown]
# W2A1

# %%
print("Hello, World!")

# %% [markdown]
# W2A2

# %%
name = input()
print(f"hello {name}")

# %% [markdown]
# W2A3

# %%
a, b =map(int,input().split())
print("Tong =", a + b)
print("Hieu =", a - b)
print("Tich =", a * b)
print("phan nguyen =", a // b)
print("phan du =", a % b)
print("chia thuc =",f"{a / b:.2f}" )

# %% [markdown]
# W2A4

# %%
a1, b1 ,c1, a2, b2, a3 = map(float, input().split())
c = ((a1 + b1 + c1) + (a2 + b2) * 2 +a3 * 3) / 10
print(f"diem trung binh = {c:.1f}")

# %% [markdown]
# W2A5

# %%
a, b = map(int,input().split())
c = a ** b
print(c)

# %% [markdown]
# W2A6

# %%
word = input()
print(ord(word))
print(chr(ord(word)-32))

# %% [markdown]
# W2A7

# %%
print(f"A = {((13 ** 2) * 3) + 5}")
print(f"B = {13 ** 2 * 3 + 5}")

# %% [markdown]
# W2A8

# %%
do_C = float(input())
do_F = (do_C * 9 / 5) + 32
print(f"{do_F:.2f}")

# %% [markdown]
# W2A9

# %%
x = float(input())
print(f"{(x * 1.4 +10):.2f}")

# %% [markdown]
# W2A10

# %%
a, b, c = map(str,input().split())
print(f"Hi {c}, {b} and {a}.")

# %% [markdown]
# W2A11

# %%
a, b = map(int,input().split())
print(f"so gio va so phut duoc chuyen sang don vi giay la : {a * 3600 + b * 60}")

# %% [markdown]
# W2A12

# %%
a = int(input())
b = a * 6 * 6
print(b)

# %% [markdown]
# W2A13

# %%
a, b = map(int,input().split ())
c = (a * b)
print(f" hang don vi cua tich giua a va b la : {c % 10}")

# %% [markdown]
# W2A14

# %%
a ,b = map(int,input().split())
a ,b = b, a
print ( a , b)

# %% [markdown]
# W2A15

# %% [markdown]
# W2A16

# %%
print("Spring\nSummer\nAutumn\nWinter")

# %% [markdown]
# W2A17

# %%
print("*\n***\n*****")

# %% [markdown]
# W2A18

# %%
print("### # #  ### ###\n #  #  #  #   #\n #  #  #  #   #\n #  # #   #   #")

# %% [markdown]
# W2A19

# %%
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")

# %% [markdown]
# W2A20

# %%
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")

# %% [markdown]
# W2A21

# %%
for i in range(10):
    print("hello world")
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
