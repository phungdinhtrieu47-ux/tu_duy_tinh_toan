# %% [markdown]
# bai 1 : Viết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two( a, b) ->
# int:

# %%
a, b = map(int, input().split())
def max_of_two (a, b):
    if a > b:
        return a
    else:
        return b
print(max_of_two(a, b))

# %% [markdown]
# bai2 : Viết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two( a, b) -> int:

# %%
a, b = map(int, input().split())
def swap(a, b):
    return b,a
print(swap(a, b))

# %% [markdown]
# bai 3 : Viết hàm kiểm tra một số có phải là số nguyên tố hay không?

# %%
a = int(input())
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True
print(is_prime(a))

# %% [markdown]
# bai4 : VIết hàm kiểm tra một số có phải số hoàn hảo hay không, xử lý trên dữ liệu kiểu số nguyên.

# %%
n = int(input())
arr = []
for i in range(1, n):
    if n % i == 0:
        arr.append(i)
if sum(arr) == n:
    print("yes")
else:
    print("no")

# %% [markdown]
# bai 5: Viết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và trả về vị trí của phần tử
# đầu tiên có giá trị k trong list số nguyên, nếu không có thì trả về -1

# %%
k = int(input())
x = list(map(int, input().split()))
if k in x:
    print(x.index(k)+1)
else:
    print(-1)

# %% [markdown]
# bai 6 : Viết hàm tính giai thừa. Nhập vào số nguyên n, trả về giai thừa của n (n!)

# %%
n = int(input())
x = 1
for i in range(1, n +1):
    x *= i
print(x)

# %% [markdown]
# bai 7 :Viết hàm giả lập một máy tính bỏ túi.
# Hàm thực hiện tính toán kết quả của phép toán giữa số \( num1 \) và \( num2 \) với toán tử \( operat
# \)
# Biết các toán tử đơn giản thực hiện phép toán lần lượt là:
# Phép trừ \( - \)
# Phép cộng \( + \)
# Phép chia \( / \)
# Phép nhân \( * \)
# Kết quả làm tròn đến chữ số thập phân thứ hai.
# Đầu vào: Hai số thực và phép toán cần thực hiện (trong số các phép toán \(+, -, *, /\)).
# Đầu ra: Kết quả phép toán

# %%
def calculator(num1, num2, operat):
    if operat == '+':
        result = num1 + num2
    elif operat == '-':
        result = num1 - num2
    elif operat == '*':
        result = num1 * num2
    elif operat == '/':
        if num2 == 0:
            return "Lỗi: Không thể chia cho 0"
        result = num1 / num2
    else:
        return "Lỗi: Phép toán không hợp lệ"

    return round(result, 2)

# %% [markdown]
# bai 8 : Khoảng cách Hamming giữa hai số nguyên là số lượng vị trí khác nhau giữa hai dãy bits tương ứng
# của chúng. Ví dụ: Khoảng cách Hamming giữa 1 (1) và 4 (100) là 2.
# Cho hai số nguyên  x và y, hãy viết hàm trả về khoảng cách Hamming giữa hai số này.
# Khoảng cách Hamming là cái tên được đặt theo tên của Richard Hamming, người giới thiệu lý
# thuyết này trong tài liệu có tính cơ sở của ông về mã phát hiện lỗi và sửa lỗi (error-detecting and
# error-correcting codes). Nó được sử dụng trong kỹ thuật viễn thông để tính số lượng các bit trong
# một từ nhị phân (binary word) bị đổi ngược, như một hình thức để ước tính số lỗi xảy ra trong quá
# trình truyền thông, và vì thế, đôi khi, nó còn được gọi là khoảng cách tín hiệu (signal distance). Việc
# phân tích trọng số Hamming của các bit còn được sử dụng trong một số ngành, bao gồm lý thuyết
# tin học, lý thuyết mã hóa, và mật mã học. Tuy vậy, khi so sánh các dãy ký tự có chiều dài khác
# nhau, hay các dãy ký tự có xu hướng không chỉ bị thay thế không thôi, mà còn bị ảnh hưởng bởi dữ
# liệu bị lồng thêm vào, hoặc bị xóa đi, phương pháp đo lường phức tạp hơn, như khoảng cách
# Levenshtein (Levenshtein distance) là một phương pháp có tác dụng và thích hợp hơn.

# %%
x, y = map(int, input("Nhập hai số: ").split())
def hamming_distance(x: int, y: int) -> int:
    xor_result = x ^ y
    return bin(xor_result).count("1")
print(hamming_distance(x, y))

# %% [markdown]
# bai 9 :Viết hàm trả về tổng các chữ số của số nguyên dương n

# %%
n = int(input())
x = 0
i = n // 10
while n != 0:
    n //= 10
    i %= 10
    x +=i
print(x)

# %% [markdown]
# bai 10 : Hai từ được gọi là đẳng cấu nếu các kí tự trong một từ có thể được ánh xạ để được từ còn lại. Ánh
# xạ một kí tự nghĩa là thay đổi toàn bộ các kí tự đó trong từ bởi một kí tự khác. Thứ tự của các kí tự
# được giữ không đổi. Hai kí tự khác nhau không thể ánh xạ đến cùng một kí tự, nhưng một kí tự có
# thể ánh xạ thành chính nó. Ví dụ, từ "abca" và "zbxz" là hai từ đẳng cấu vì ta có thể ánh xạ 'a' thành
# 'z', 'b' thành 'b' và 'c' thành 'x'.
# Viết hàm  trả về \(true\) nếu hai từ \(a\) và \(b\) là đẳng cấu, ngược lại \(false\). Bạn có thể giả sử hai từ đầu vào có cùng độ dài.

# %%
def is_isomorphic(a, b):
    map_a_b = {}
    map_b_a = {}

    for i in range(len(a)):
        char_a = a[i]
        char_b = b[i]
        if char_a in map_a_b:
            if map_a_b[char_a] != char_b:
                return False
        else:
            map_a_b[char_a] = char_b
        if char_b in map_b_a:
            if map_b_a[char_b] != char_a:
                return False
        else:
            map_b_a[char_b] = char_a

    return True

# %% [markdown]
# bai 11 : Viết hàm is_product_divisible_by_10(a, b) trả về True nếu tích a*b chia hết cho 10, ngược lại False.

# %%
a, b = map(int, input().split())
def is_product_divisible_by_10(a, b):
    product = a * b
    if product % 10 == 0:
        return True
    else:
        return False
print(is_product_divisible_by_10(a, b))

# %% [markdown]
# bai 12 : Viết hàm divide_with_remainder(dividend, divisor) trả về bộ (q, r) sao cho dividend = divisor*q + r và
# 0 <= |r| < |divisor|.

# %%
def divide_with_remainder(dividend, divisor):
    if divisor == 0:
        raise ValueError("Divisor must not be 0")
    q = dividend // divisor
    r = dividend - divisor * q
    if abs(r) >= abs(divisor):
        if r > 0:
            q += 1
        else:
            q -= 1
        r = dividend - divisor * q
    return q, r

# %% [markdown]
# bai 13 : Viết hàm max_of_two(a, b) trả về số lớn hơn trong hai số.

# %%
a, b = map(int, input().split())
def max_of_two (a, b):
    if a > b:
        return a
    else:
        return b
print(max_of_two(a, b))

# %% [markdown]
# bai 14 : Viết hàm compute(a, b, op) thực hiện phép tính a (+|-|*|/) b tùy theo ký tự op.

# %%
def compute(a, b, op):
    if op == '+':
        return a + b
    elif op == '-':
        return a - b
    elif op == '*':
        return a * b
    elif op == '/':
        if b == 0:
            raise ValueError("Không thể chia cho 0")
        return a / b
    else:
        raise ValueError("Toán tử không hợp lệ")

# %% [markdown]
# bai 15 :Viết hàm is_right_triangle(a, b, c) trả về True nếu ba số có thể là ba cạnh của tam giác vuông.

# %%
def is_right_triangle(a, b, c):
    a, b, c = sorted([a, b, c])
    if a + b <= c:
        return Falses
    return a*a + b*b == c*c
